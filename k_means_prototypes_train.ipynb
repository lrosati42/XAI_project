# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

import plotly as py
import plotly.graph_objs as go

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

# %%
data_train = pd.read_csv("data/bank_data.csv", header=0)
data_train
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
data_train.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
data_train.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         1.000000e+05  80846.000000   8.084600e+04  100000.000000
# mean          1.176045e+07   1076.456089   1.378277e+06   18472.412336
# std           3.178394e+07   1475.403791   1.081360e+06   12174.992609
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.796520e+05    705.000000   8.488440e+05   10214.162500
# 50%           3.122460e+05    724.000000   1.174162e+06   16220.300000
# 75%           5.249420e+05    741.000000   1.650663e+06   24012.057500
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count            100000.000000                  46859.000000
# mean                 18.199141                     34.901321
# std                   7.015324                     21.997829
# min                   3.600000                      0.000000
# ...

# %%
data_train.isnull().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
df_cleaned = data_train.dropna(axis=0)

# %%
df_cleaned_numeric = df_cleaned.select_dtypes(include=['float64', 'int64'])
df_cleaned_numeric
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 2               99999999.0         741.0      2231892.0      29200.53
# 6                 217646.0         730.0      1184194.0      10855.08
# 8                 548746.0         678.0      2559110.0      18660.28
# 10              99999999.0         728.0       714628.0      11851.06
# 12              99999999.0         740.0       776188.0      11578.22
# ...                    ...           ...            ...           ...
# 99990           99999999.0         742.0      1190046.0      11969.81
# 99993              44484.0         717.0      1152426.0       6280.64
# 99994             210584.0         719.0       783389.0       3727.61
# 99996           99999999.0         732.0      1289416.0      13109.05
# 99997             103136.0         742.0      1150545.0       7315.57
#
#        Years of Credit History  Months since last delinquent  \
# 2                         14.9                          29.0
# ...

# %%
inertia = []
for n in range(1 , 15):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
    algorithm.fit(df_cleaned_numeric)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 15) , inertia , 'o')
plt.plot(np.arange(1 , 15) , inertia , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()

# %%
features=list(df_cleaned_numeric.columns) 
 
data=df_cleaned_numeric[features]


# Inizializza e addestra l'algoritmo KMeans
k_means = KMeans(n_clusters=3, init='k-means++', max_iter=300, tol=0.0001, random_state=111, algorithm='elkan')
y=k_means.fit_predict(data)

# %%
data["clusters"]=y

#print(data.head(50))
print(data.head(10)["clusters"])
data[:10].to_csv('clusters_train.csv')
# Out:
# 2     0
# 6     1
# 8     1
# 10    0
# 12    0
# 14    1
# 17    1
# 20    1
# 25    1
# 28    0
# Name: clusters, dtype: int32

# %%
pca_num_components = 2

reduced_data = PCA(n_components=pca_num_components).fit_transform(data)
results = pd.DataFrame(reduced_data,columns=['pca1','pca2'])

sns.scatterplot(x="pca1", y="pca2", hue=data['clusters'], data=results)
plt.title('K-means Clustering with 2 dimensions')
plt.show()
